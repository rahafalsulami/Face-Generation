# %% [markdown]
# <a href="https://colab.research.google.com/github/rahafalsulami/Face-Generation/blob/main/CIFAR-10/new_training_for_SD2GAN_cifar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
from keras.models import model_from_json
json_file = open('/content/Siamese_net_noise_Cifar-10.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
sn_model = model_from_json(loaded_model_json)
sn_model.load_weights("/content/Siamese_net_noise_Cifar-10.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
# example of a dcgan on cifar10
from numpy import expand_dims
import numpy as np
from numpy import zeros
from numpy import ones
from numpy import vstack
from numpy.random import randn
from numpy.random import randint
from keras.datasets.cifar10 import load_data
# from tf.keras.optimizers import Adam tf.keras.optimizers.Adam
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from matplotlib import pyplot
import tensorflow as tf

# %%
# define the standalone discriminator model
def define_discriminator(in_shape=(32,32,3)):
	model = Sequential()
	# normal
	model.add(Conv2D(64, (3,3), padding='same', input_shape=in_shape))
	model.add(LeakyReLU(alpha=0.2))
	# downsample
	model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# downsample
	model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# downsample
	model.add(Conv2D(256, (3,3), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dropout(0.4))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = tf.keras.optimizers.Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
	return model

# define the standalone generator model
def define_generator(latent_dim):
	model = Sequential()
	# foundation for 4x4 image
	n_nodes = 256 * 4 * 4
	model.add(Dense(n_nodes, input_dim=latent_dim))
	model.add(LeakyReLU(alpha=0.2))
	model.add(Reshape((4, 4, 256)))
	# upsample to 8x8
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# upsample to 16x16
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# upsample to 32x32
	model.add(Conv2DTranspose(128, (4,4), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# output layer
	model.add(Conv2D(3, (3,3), activation='tanh', padding='same'))
	return model

def define_discriminator2():
	model = Sequential()
	model.add(Dense(128, input_shape=(1,), activation=tf.nn.relu))
	model.add(Dense(1, activation='sigmoid'))

	opt = tf.keras.optimizers.Adam(lr=0.00009, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model, d2_model, sn_model, latent_dim):
  # make weights in the discriminator not trainable
  d_model.trainable = False
  d2_model.trainable = False
  sn_model.trainable = False

  z = tf.keras.layers.Input(shape=(latent_dim,))
  g_img = g_model(z)
  imgs1 = tf.keras.layers.Input((32,32,3))
  imgs2 = tf.keras.layers.Input((32,32,3))

  similarity = sn_model([imgs1, imgs2])
  similarity_validity = d2_model(similarity)
  validity = d_model(g_img)

  model = tf.keras.models.Model([z, [imgs1, imgs2]], [validity, similarity_validity])

  opt = tf.keras.optimizers.Adam(lr=0.0002, beta_1=0.5)
  model.compile(loss='binary_crossentropy', optimizer=opt)
  return model

# %%
# load and prepare cifar10 training images
def load_real_samples():
	# load cifar10 dataset
	(trainX, _), (_, _) = load_data()
	# convert from unsigned ints to floats
	X = trainX.astype('float32')
	# scale from [0,255] to [-1,1]
	X = (X - 127.5) / 127.5
	return X

# select real samples
def generate_real_samples(dataset, n_samples):
	# choose random instances
	ix = randint(0, dataset.shape[0], n_samples)
	# retrieve selected images
	X = dataset[ix]
	# generate 'real' class labels (1)
	y = ones((n_samples, 1))
	return X, y

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_samples):
	# generate points in the latent space
	x_input = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	x_input = x_input.reshape(n_samples, latent_dim)
	return x_input

# use the generator to generate n fake examples, with class labels
def generate_fake_samples(g_model, latent_dim, n_samples):
	# generate points in latent space
	x_input = generate_latent_points(latent_dim, n_samples)
	# predict outputs
	X = g_model.predict(x_input)
	# create 'fake' class labels (0)
	y = zeros((n_samples, 1))
	return X, y

# create and save a plot of generated images
def save_plot(examples, epoch, n=2):
	# scale from [-1,1] to [0,1]
	examples = (examples + 1) / 2.0
	# plot images
	for i in range(n * n):
		# define subplot
		pyplot.subplot(n, n, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(examples[i])
	# save plot to file
	filename = 'generated_plot_e%03d.png' % (epoch+1)
	pyplot.savefig(filename)
	pyplot.close()


# evaluate the discriminator, plot generated images, save generator model
def summarize_performance(epoch, g_model, d_model, d2_model, sn_model, dataset, latent_dim, n_samples=150):
	# prepare real samples
	X_real, y_real = generate_real_samples(dataset, n_samples)
	# evaluate discriminator on real examples
	_, acc_real = d_model.evaluate(X_real, y_real, verbose=0)
	# prepare fake examples
	x_fake, y_fake = generate_fake_samples(g_model, latent_dim, n_samples)
	# evaluate discriminator on fake examples
	_, acc_fake = d_model.evaluate(x_fake, y_fake, verbose=0)
	# print(X_real.shape[0])
	# rand_idx = np.random.randint(0, n_samples, int(n_samples/2))
	# rand_idx2 = np.array([i for i in range(n_samples) if i not in rand_idx])
	splited_batch = np.split(X_real, 2)
	# print(rand_idx.shape, rand_idx2.shape)
	batch1 = splited_batch[0]
	batch2 = splited_batch[1]
	sim_real = sn_model.predict([batch1, batch2])
	y_sim_real = ones((sim_real.shape[0], 1))
	# rand_idx = np.random.randint(0, x_fake.shape[0])
	# rand_idx2 = np.array([i for i in range(x_fake.shape[0]) if i not in rand_idx])
	splited_batch = np.split(x_fake, 2)
	# batch1 = x_fake[rand_idx]
	# batch2 = x_fake[rand_idx2]
	batch1 = splited_batch[0]
	batch2 = splited_batch[1]
	sim_fake = sn_model.predict([batch1, batch2])
	y_sim_fake = zeros((sim_real.shape[0], 1))
	_, acc2_real = d2_model.evaluate(sim_real, y_sim_real, verbose=0)
	_, acc2_fake = d2_model.evaluate(sim_fake, y_sim_fake, verbose=0)
	# summarize discriminator performance
	print('>Accuracy real: %.0f%%, fake: %.0f%% \t >D2 Accuracy real: %.0f%%, fake: %.0f%%' % (acc_real*100, acc_fake*100, acc2_real*100, acc2_fake*100))
	# save plot
	save_plot(x_fake, epoch)
	# save the generator model tile file
	filename = 'generator_model_%03d.h5' % (epoch+1)
	g_model.save(filename)

# %%
# train the generator and discriminator
def train(g_model, d_model, d2_model, sn_model, gan_model, dataset, latent_dim, n_epochs=200, n_batch=128):
  bat_per_epo = int(dataset.shape[0] / n_batch)
  half_batch = int(n_batch / 2)
  # manually enumerate epochs
  for i in range(n_epochs):
    # enumerate batches over the training set
    for j in range(bat_per_epo):
      # get randomly selected 'real' samples
      X_real, y_real = generate_real_samples(dataset, half_batch)
      # update discriminator model weights
      d_loss1, _ = d_model.train_on_batch(X_real, y_real)
      splited_batch = np.split(X_real, 2)
      batch1 = splited_batch[0]
      batch2 = splited_batch[1]
      sim_real = sn_model.predict([batch1, batch2])
      y_sim_real = ones((sim_real.shape[0], 1))
      d2_loss1, _ = d2_model.train_on_batch(sim_real, y_sim_real)
      # generate 'fake' examples
      X_fake, y_fake = generate_fake_samples(g_model, latent_dim, half_batch)
      # update discriminator model weights
      d_loss2, _ = d_model.train_on_batch(X_fake, y_fake)
      splited_batch = np.split(X_fake, 2)
      batch1 = splited_batch[0]
      batch2 = splited_batch[1]
      sim_fake = sn_model.predict([batch1, batch2])
      y_sim_fake = zeros((sim_fake.shape[0], 1))
      d2_loss1, _ = d2_model.train_on_batch(sim_fake, y_sim_fake)
      # prepare points in latent space as input for the generator
      X_gan = generate_latent_points(latent_dim, n_batch)
      # print(X_gan.shape)
      X_gan_f, y_gan_f = generate_fake_samples(g_model, latent_dim, n_batch*2)
      splited_batch = np.split(X_gan_f, 2)
      batch1 = splited_batch[0]
      batch2 = splited_batch[1]
      # sim_gan = sn_model.predict([batch1, batch2])
      # y_sim_gan = ones((sim_gan.shape[0], 1))
      # create inverted labels for the fake samples
      y_gan = ones((n_batch, 1))
      # update the generator via the discriminator's error
      g_loss = gan_model.train_on_batch([X_gan, [batch1, batch2]], y_gan)
      # print(g_loss)
      # summarize loss on this batch
      print('>%d, %d/%d, d1=%.3f, d2=%.3f g=%.3f' %
        (i+1, j+1, bat_per_epo, d_loss1, d_loss2, g_loss[0]))
      # evaluate the model performance, sometimes
      if (i+1) % 10 == 0:
        summarize_performance(i, g_model, d_model, d2_model, sn_model, dataset, latent_dim)

# %%
# size of the latent space
latent_dim = 100
# create the discriminator
d_model = define_discriminator()
d2_model = define_discriminator2()
# create the generator
g_model = define_generator(latent_dim)
# create the gan
gan_model = define_gan(g_model, d_model, d2_model, sn_model, latent_dim)
dataset = load_real_samples()
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
train(g_model, d_model, d2_model, sn_model, gan_model, dataset, latent_dim)
# Out:
# Streaming output truncated to the last 5000 lines.
# >Accuracy real: 64%, fake: 96% 	 >D2 Accuracy real: 52%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 285/390, d1=0.383, d2=0.502 g=2.201
# >Accuracy real: 69%, fake: 95% 	 >D2 Accuracy real: 44%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 286/390, d1=0.406, d2=0.540 g=2.389
# >Accuracy real: 74%, fake: 95% 	 >D2 Accuracy real: 48%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 287/390, d1=0.371, d2=0.492 g=2.268
# >Accuracy real: 72%, fake: 97% 	 >D2 Accuracy real: 48%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 288/390, d1=0.402, d2=0.382 g=2.233
# >Accuracy real: 75%, fake: 92% 	 >D2 Accuracy real: 56%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 289/390, d1=0.363, d2=0.434 g=2.046
# >Accuracy real: 79%, fake: 87% 	 >D2 Accuracy real: 41%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 290/390, d1=0.460, d2=0.460 g=2.100
# >Accuracy real: 75%, fake: 87% 	 >D2 Accuracy real: 56%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 291/390, d1=0.483, d2=0.782 g=2.124
# >Accuracy real: 78%, fake: 85% 	 >D2 Accuracy real: 44%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 292/390, d1=0.444, d2=0.463 g=2.176
# >Accuracy real: 70%, fake: 96% 	 >D2 Accuracy real: 37%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 293/390, d1=0.401, d2=0.473 g=2.177
# >Accuracy real: 69%, fake: 97% 	 >D2 Accuracy real: 49%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 294/390, d1=0.416, d2=0.582 g=2.266
# >Accuracy real: 72%, fake: 89% 	 >D2 Accuracy real: 57%, fake: 63%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 295/390, d1=0.463, d2=0.609 g=2.193
# >Accuracy real: 66%, fake: 90% 	 >D2 Accuracy real: 45%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 296/390, d1=0.451, d2=0.457 g=2.185
# >Accuracy real: 67%, fake: 93% 	 >D2 Accuracy real: 47%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 297/390, d1=0.404, d2=0.592 g=2.253
# >Accuracy real: 68%, fake: 91% 	 >D2 Accuracy real: 49%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 298/390, d1=0.441, d2=0.429 g=2.201
# >Accuracy real: 67%, fake: 93% 	 >D2 Accuracy real: 47%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 299/390, d1=0.429, d2=0.445 g=2.180
# >Accuracy real: 71%, fake: 95% 	 >D2 Accuracy real: 43%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 300/390, d1=0.397, d2=0.504 g=2.214
# >Accuracy real: 67%, fake: 93% 	 >D2 Accuracy real: 44%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 301/390, d1=0.433, d2=0.508 g=2.030
# >Accuracy real: 75%, fake: 90% 	 >D2 Accuracy real: 49%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 302/390, d1=0.438, d2=0.480 g=2.126
# >Accuracy real: 71%, fake: 89% 	 >D2 Accuracy real: 47%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 303/390, d1=0.452, d2=0.463 g=2.115
# >Accuracy real: 72%, fake: 89% 	 >D2 Accuracy real: 47%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 304/390, d1=0.387, d2=0.482 g=2.123
# >Accuracy real: 66%, fake: 88% 	 >D2 Accuracy real: 51%, fake: 63%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 305/390, d1=0.443, d2=0.571 g=2.235
# >Accuracy real: 69%, fake: 96% 	 >D2 Accuracy real: 55%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 306/390, d1=0.428, d2=0.391 g=2.138
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 48%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 307/390, d1=0.451, d2=0.566 g=2.068
# >Accuracy real: 73%, fake: 89% 	 >D2 Accuracy real: 44%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 308/390, d1=0.393, d2=0.540 g=2.110
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 41%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 309/390, d1=0.423, d2=0.436 g=2.109
# >Accuracy real: 62%, fake: 90% 	 >D2 Accuracy real: 53%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 310/390, d1=0.428, d2=0.473 g=2.253
# >Accuracy real: 66%, fake: 85% 	 >D2 Accuracy real: 44%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 311/390, d1=0.491, d2=0.409 g=2.126
# >Accuracy real: 76%, fake: 89% 	 >D2 Accuracy real: 51%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 312/390, d1=0.465, d2=0.630 g=2.166
# >Accuracy real: 63%, fake: 90% 	 >D2 Accuracy real: 41%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 313/390, d1=0.435, d2=0.573 g=2.233
# >Accuracy real: 68%, fake: 95% 	 >D2 Accuracy real: 51%, fake: 57%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 314/390, d1=0.397, d2=0.506 g=2.154
# >Accuracy real: 69%, fake: 91% 	 >D2 Accuracy real: 57%, fake: 59%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 315/390, d1=0.491, d2=0.546 g=2.097
# >Accuracy real: 65%, fake: 91% 	 >D2 Accuracy real: 56%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 316/390, d1=0.413, d2=0.501 g=2.176
# >Accuracy real: 68%, fake: 95% 	 >D2 Accuracy real: 49%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 317/390, d1=0.405, d2=0.544 g=2.137
# >Accuracy real: 74%, fake: 94% 	 >D2 Accuracy real: 49%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 318/390, d1=0.423, d2=0.458 g=2.303
# >Accuracy real: 76%, fake: 89% 	 >D2 Accuracy real: 49%, fake: 61%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 319/390, d1=0.440, d2=0.576 g=2.028
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 52%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 320/390, d1=0.400, d2=0.421 g=2.278
# >Accuracy real: 74%, fake: 91% 	 >D2 Accuracy real: 56%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 321/390, d1=0.401, d2=0.466 g=2.209
# >Accuracy real: 71%, fake: 88% 	 >D2 Accuracy real: 44%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 322/390, d1=0.482, d2=0.563 g=2.106
# >Accuracy real: 70%, fake: 91% 	 >D2 Accuracy real: 48%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 323/390, d1=0.446, d2=0.410 g=2.195
# >Accuracy real: 69%, fake: 95% 	 >D2 Accuracy real: 44%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 324/390, d1=0.459, d2=0.549 g=2.212
# >Accuracy real: 71%, fake: 93% 	 >D2 Accuracy real: 36%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 325/390, d1=0.392, d2=0.491 g=2.210
# >Accuracy real: 71%, fake: 90% 	 >D2 Accuracy real: 44%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 326/390, d1=0.429, d2=0.450 g=2.222
# >Accuracy real: 79%, fake: 93% 	 >D2 Accuracy real: 45%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 327/390, d1=0.391, d2=0.444 g=2.296
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 52%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 328/390, d1=0.434, d2=0.460 g=2.047
# >Accuracy real: 73%, fake: 92% 	 >D2 Accuracy real: 53%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 329/390, d1=0.405, d2=0.498 g=2.110
# >Accuracy real: 72%, fake: 89% 	 >D2 Accuracy real: 53%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 330/390, d1=0.435, d2=0.505 g=2.220
# >Accuracy real: 70%, fake: 89% 	 >D2 Accuracy real: 51%, fake: 63%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 331/390, d1=0.433, d2=0.384 g=2.306
# >Accuracy real: 71%, fake: 87% 	 >D2 Accuracy real: 52%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 332/390, d1=0.407, d2=0.494 g=2.200
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 52%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 333/390, d1=0.436, d2=0.475 g=2.157
# >Accuracy real: 65%, fake: 93% 	 >D2 Accuracy real: 61%, fake: 61%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 334/390, d1=0.465, d2=0.495 g=2.035
# >Accuracy real: 73%, fake: 87% 	 >D2 Accuracy real: 40%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 335/390, d1=0.448, d2=0.551 g=2.004
# >Accuracy real: 69%, fake: 92% 	 >D2 Accuracy real: 49%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 336/390, d1=0.431, d2=0.558 g=2.187
# >Accuracy real: 68%, fake: 95% 	 >D2 Accuracy real: 37%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 337/390, d1=0.399, d2=0.642 g=2.183
# >Accuracy real: 71%, fake: 92% 	 >D2 Accuracy real: 57%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 338/390, d1=0.383, d2=0.421 g=2.158
# >Accuracy real: 67%, fake: 93% 	 >D2 Accuracy real: 43%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 339/390, d1=0.436, d2=0.540 g=2.291
# >Accuracy real: 68%, fake: 93% 	 >D2 Accuracy real: 49%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 340/390, d1=0.414, d2=0.497 g=2.057
# >Accuracy real: 73%, fake: 91% 	 >D2 Accuracy real: 52%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 341/390, d1=0.447, d2=0.586 g=2.233
# >Accuracy real: 68%, fake: 94% 	 >D2 Accuracy real: 53%, fake: 84%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 342/390, d1=0.434, d2=0.382 g=2.226
# >Accuracy real: 77%, fake: 89% 	 >D2 Accuracy real: 41%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 343/390, d1=0.452, d2=0.505 g=2.122
# >Accuracy real: 72%, fake: 89% 	 >D2 Accuracy real: 55%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 344/390, d1=0.457, d2=0.456 g=2.147
# >Accuracy real: 75%, fake: 89% 	 >D2 Accuracy real: 51%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 345/390, d1=0.441, d2=0.533 g=2.134
# >Accuracy real: 73%, fake: 92% 	 >D2 Accuracy real: 56%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 346/390, d1=0.417, d2=0.573 g=2.244
# >Accuracy real: 69%, fake: 91% 	 >D2 Accuracy real: 49%, fake: 61%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 347/390, d1=0.428, d2=0.422 g=2.238
# >Accuracy real: 71%, fake: 92% 	 >D2 Accuracy real: 64%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 348/390, d1=0.398, d2=0.458 g=2.141
# >Accuracy real: 67%, fake: 93% 	 >D2 Accuracy real: 44%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 349/390, d1=0.413, d2=0.415 g=2.186
# >Accuracy real: 76%, fake: 90% 	 >D2 Accuracy real: 45%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 350/390, d1=0.441, d2=0.527 g=2.181
# >Accuracy real: 77%, fake: 96% 	 >D2 Accuracy real: 48%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 351/390, d1=0.408, d2=0.526 g=2.268
# >Accuracy real: 65%, fake: 92% 	 >D2 Accuracy real: 43%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 352/390, d1=0.444, d2=0.532 g=2.114
# >Accuracy real: 73%, fake: 93% 	 >D2 Accuracy real: 44%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 353/390, d1=0.406, d2=0.523 g=2.068
# >Accuracy real: 79%, fake: 90% 	 >D2 Accuracy real: 60%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 354/390, d1=0.445, d2=0.536 g=2.096
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 48%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 355/390, d1=0.442, d2=0.420 g=2.077
# >Accuracy real: 71%, fake: 89% 	 >D2 Accuracy real: 52%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 356/390, d1=0.467, d2=0.524 g=1.996
# >Accuracy real: 71%, fake: 88% 	 >D2 Accuracy real: 45%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 357/390, d1=0.430, d2=0.609 g=2.008
# >Accuracy real: 78%, fake: 86% 	 >D2 Accuracy real: 39%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 358/390, d1=0.416, d2=0.450 g=2.037
# >Accuracy real: 73%, fake: 85% 	 >D2 Accuracy real: 43%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 359/390, d1=0.465, d2=0.445 g=2.143
# >Accuracy real: 83%, fake: 88% 	 >D2 Accuracy real: 56%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 360/390, d1=0.469, d2=0.600 g=2.112
# >Accuracy real: 68%, fake: 91% 	 >D2 Accuracy real: 49%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 361/390, d1=0.435, d2=0.493 g=2.192
# >Accuracy real: 71%, fake: 89% 	 >D2 Accuracy real: 49%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 362/390, d1=0.451, d2=0.491 g=2.140
# >Accuracy real: 74%, fake: 94% 	 >D2 Accuracy real: 55%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 363/390, d1=0.408, d2=0.519 g=2.067
# >Accuracy real: 65%, fake: 96% 	 >D2 Accuracy real: 45%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 364/390, d1=0.425, d2=0.486 g=2.200
# >Accuracy real: 75%, fake: 91% 	 >D2 Accuracy real: 43%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 365/390, d1=0.445, d2=0.510 g=2.232
# >Accuracy real: 73%, fake: 88% 	 >D2 Accuracy real: 49%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 366/390, d1=0.424, d2=0.650 g=2.159
# >Accuracy real: 73%, fake: 95% 	 >D2 Accuracy real: 52%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 367/390, d1=0.404, d2=0.486 g=2.163
# >Accuracy real: 65%, fake: 93% 	 >D2 Accuracy real: 51%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 368/390, d1=0.400, d2=0.476 g=2.148
# >Accuracy real: 68%, fake: 91% 	 >D2 Accuracy real: 44%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 369/390, d1=0.443, d2=0.478 g=2.228
# >Accuracy real: 73%, fake: 93% 	 >D2 Accuracy real: 57%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 370/390, d1=0.410, d2=0.390 g=2.198
# >Accuracy real: 74%, fake: 89% 	 >D2 Accuracy real: 60%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 371/390, d1=0.403, d2=0.503 g=2.234
# >Accuracy real: 73%, fake: 91% 	 >D2 Accuracy real: 52%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 372/390, d1=0.423, d2=0.453 g=2.108
# >Accuracy real: 79%, fake: 89% 	 >D2 Accuracy real: 61%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 373/390, d1=0.444, d2=0.432 g=2.140
# >Accuracy real: 74%, fake: 87% 	 >D2 Accuracy real: 43%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 374/390, d1=0.415, d2=0.623 g=2.186
# >Accuracy real: 75%, fake: 86% 	 >D2 Accuracy real: 63%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 375/390, d1=0.453, d2=0.495 g=2.241
# >Accuracy real: 61%, fake: 96% 	 >D2 Accuracy real: 43%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 376/390, d1=0.429, d2=0.572 g=2.278
# >Accuracy real: 70%, fake: 94% 	 >D2 Accuracy real: 52%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 377/390, d1=0.411, d2=0.527 g=2.187
# >Accuracy real: 64%, fake: 89% 	 >D2 Accuracy real: 48%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 378/390, d1=0.439, d2=0.502 g=2.142
# >Accuracy real: 73%, fake: 91% 	 >D2 Accuracy real: 47%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 379/390, d1=0.435, d2=0.604 g=2.111
# >Accuracy real: 69%, fake: 94% 	 >D2 Accuracy real: 49%, fake: 87%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 380/390, d1=0.404, d2=0.467 g=2.145
# >Accuracy real: 72%, fake: 91% 	 >D2 Accuracy real: 56%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 381/390, d1=0.437, d2=0.427 g=2.120
# >Accuracy real: 67%, fake: 86% 	 >D2 Accuracy real: 49%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 382/390, d1=0.464, d2=0.464 g=2.063
# >Accuracy real: 77%, fake: 95% 	 >D2 Accuracy real: 53%, fake: 80%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 383/390, d1=0.362, d2=0.480 g=2.034
# >Accuracy real: 68%, fake: 89% 	 >D2 Accuracy real: 52%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 384/390, d1=0.479, d2=0.460 g=2.099
# >Accuracy real: 73%, fake: 93% 	 >D2 Accuracy real: 53%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 385/390, d1=0.399, d2=0.584 g=2.254
# >Accuracy real: 74%, fake: 92% 	 >D2 Accuracy real: 39%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 386/390, d1=0.416, d2=0.433 g=2.232
# >Accuracy real: 67%, fake: 90% 	 >D2 Accuracy real: 60%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 387/390, d1=0.449, d2=0.518 g=2.106
# >Accuracy real: 69%, fake: 89% 	 >D2 Accuracy real: 48%, fake: 63%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 388/390, d1=0.450, d2=0.516 g=2.113
# >Accuracy real: 76%, fake: 91% 	 >D2 Accuracy real: 51%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 389/390, d1=0.409, d2=0.429 g=2.171
# >Accuracy real: 69%, fake: 91% 	 >D2 Accuracy real: 40%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >190, 390/390, d1=0.431, d2=0.480 g=2.158
# >Accuracy real: 73%, fake: 95% 	 >D2 Accuracy real: 52%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >191, 1/390, d1=0.375, d2=0.392 g=2.058
# >191, 2/390, d1=0.453, d2=0.504 g=2.096
# >191, 3/390, d1=0.519, d2=0.587 g=2.126
# >191, 4/390, d1=0.591, d2=0.574 g=2.029
# >191, 5/390, d1=0.536, d2=0.513 g=2.182
# >191, 6/390, d1=0.481, d2=0.480 g=2.075
# >191, 7/390, d1=0.608, d2=0.481 g=2.117
# >191, 8/390, d1=0.472, d2=0.595 g=2.233
# >191, 9/390, d1=0.537, d2=0.550 g=2.107
# >191, 10/390, d1=0.558, d2=0.507 g=2.199
# >191, 11/390, d1=0.513, d2=0.446 g=2.111
# >191, 12/390, d1=0.389, d2=0.471 g=2.192
# >191, 13/390, d1=0.600, d2=0.440 g=2.207
# >191, 14/390, d1=0.402, d2=0.494 g=2.109
# >191, 15/390, d1=0.569, d2=0.474 g=2.140
# >191, 16/390, d1=0.509, d2=0.566 g=2.146
# >191, 17/390, d1=0.465, d2=0.409 g=2.108
# >191, 18/390, d1=0.506, d2=0.424 g=2.096
# >191, 19/390, d1=0.476, d2=0.644 g=2.189
# >191, 20/390, d1=0.526, d2=0.560 g=2.170
# >191, 21/390, d1=0.621, d2=0.438 g=2.203
# >191, 22/390, d1=0.594, d2=0.426 g=2.118
# >191, 23/390, d1=0.585, d2=0.431 g=2.031
# >191, 24/390, d1=0.482, d2=0.452 g=2.080
# >191, 25/390, d1=0.441, d2=0.531 g=2.108
# >191, 26/390, d1=0.349, d2=0.591 g=2.129
# >191, 27/390, d1=0.480, d2=0.493 g=2.199
# >191, 28/390, d1=0.528, d2=0.459 g=2.339
# >191, 29/390, d1=0.751, d2=0.464 g=2.082
# >191, 30/390, d1=0.430, d2=0.553 g=2.147
# >191, 31/390, d1=0.563, d2=0.494 g=2.190
# >191, 32/390, d1=0.628, d2=0.479 g=2.131
# >191, 33/390, d1=0.518, d2=0.471 g=2.220
# >191, 34/390, d1=0.511, d2=0.395 g=2.187
# >191, 35/390, d1=0.618, d2=0.501 g=2.092
# >191, 36/390, d1=0.390, d2=0.499 g=1.942
# >191, 37/390, d1=0.543, d2=0.749 g=2.219
# >191, 38/390, d1=0.450, d2=0.774 g=2.289
# >191, 39/390, d1=0.717, d2=0.514 g=2.209
# >191, 40/390, d1=0.640, d2=0.519 g=2.074
# >191, 41/390, d1=0.621, d2=0.497 g=2.198
# >191, 42/390, d1=0.569, d2=0.532 g=2.198
# >191, 43/390, d1=0.494, d2=0.440 g=2.049
# >191, 44/390, d1=0.533, d2=0.597 g=2.210
# >191, 45/390, d1=0.497, d2=0.394 g=2.241
# >191, 46/390, d1=0.567, d2=0.528 g=2.332
# >191, 47/390, d1=0.508, d2=0.505 g=2.202
# >191, 48/390, d1=0.625, d2=0.549 g=2.132
# >191, 49/390, d1=0.460, d2=0.453 g=2.298
# >191, 50/390, d1=0.607, d2=0.463 g=2.249
# >191, 51/390, d1=0.438, d2=0.394 g=2.142
# >191, 52/390, d1=0.535, d2=0.441 g=2.201
# >191, 53/390, d1=0.546, d2=0.599 g=2.136
# >191, 54/390, d1=0.561, d2=0.469 g=2.026
# >191, 55/390, d1=0.555, d2=0.417 g=2.045
# >191, 56/390, d1=0.513, d2=0.725 g=2.093
# >191, 57/390, d1=0.404, d2=0.471 g=2.062
# >191, 58/390, d1=0.478, d2=0.588 g=2.110
# >191, 59/390, d1=0.582, d2=0.416 g=2.245
# >191, 60/390, d1=0.559, d2=0.476 g=2.099
# >191, 61/390, d1=0.613, d2=0.575 g=1.958
# >191, 62/390, d1=0.465, d2=0.484 g=2.233
# >191, 63/390, d1=0.489, d2=0.437 g=2.096
# >191, 64/390, d1=0.452, d2=0.404 g=2.141
# >191, 65/390, d1=0.392, d2=0.485 g=2.202
# >191, 66/390, d1=0.545, d2=0.551 g=2.315
# >191, 67/390, d1=0.511, d2=0.505 g=2.315
# >191, 68/390, d1=0.586, d2=0.431 g=2.192
# >191, 69/390, d1=0.561, d2=0.547 g=2.086
# >191, 70/390, d1=0.572, d2=0.502 g=2.093
# >191, 71/390, d1=0.543, d2=0.475 g=2.183
# >191, 72/390, d1=0.456, d2=0.714 g=2.367
# >191, 73/390, d1=0.615, d2=0.376 g=2.179
# >191, 74/390, d1=0.455, d2=0.590 g=2.250
# >191, 75/390, d1=0.511, d2=0.504 g=2.327
# >191, 76/390, d1=0.664, d2=0.499 g=2.139
# >191, 77/390, d1=0.614, d2=0.474 g=2.160
# >191, 78/390, d1=0.647, d2=0.467 g=2.022
# >191, 79/390, d1=0.490, d2=0.517 g=2.038
# >191, 80/390, d1=0.452, d2=0.681 g=2.037
# >191, 81/390, d1=0.432, d2=0.523 g=2.256
# >191, 82/390, d1=0.497, d2=0.496 g=2.079
# >191, 83/390, d1=0.630, d2=0.468 g=2.185
# >191, 84/390, d1=0.598, d2=0.562 g=2.279
# >191, 85/390, d1=0.438, d2=0.424 g=2.406
# >191, 86/390, d1=0.689, d2=0.443 g=2.235
# >191, 87/390, d1=0.546, d2=0.438 g=1.966
# >191, 88/390, d1=0.558, d2=0.579 g=1.980
# >191, 89/390, d1=0.584, d2=0.546 g=2.253
# >191, 90/390, d1=0.675, d2=0.545 g=2.199
# >191, 91/390, d1=0.585, d2=0.500 g=2.241
# >191, 92/390, d1=0.453, d2=0.536 g=2.175
# >191, 93/390, d1=0.470, d2=0.481 g=2.204
# >191, 94/390, d1=0.462, d2=0.461 g=2.187
# >191, 95/390, d1=0.641, d2=0.414 g=2.292
# >191, 96/390, d1=0.626, d2=0.559 g=2.133
# >191, 97/390, d1=0.556, d2=0.501 g=2.152
# >191, 98/390, d1=0.506, d2=0.474 g=2.340
# >191, 99/390, d1=0.549, d2=0.506 g=2.244
# >191, 100/390, d1=0.456, d2=0.381 g=2.140
# >191, 101/390, d1=0.530, d2=0.434 g=2.079
# >191, 102/390, d1=0.552, d2=0.623 g=2.138
# >191, 103/390, d1=0.480, d2=0.492 g=2.177
# >191, 104/390, d1=0.564, d2=0.445 g=2.141
# >191, 105/390, d1=0.475, d2=0.452 g=2.151
# >191, 106/390, d1=0.465, d2=0.528 g=2.211
# >191, 107/390, d1=0.628, d2=0.550 g=2.174
# >191, 108/390, d1=0.512, d2=0.482 g=2.220
# >191, 109/390, d1=0.520, d2=0.386 g=2.097
# >191, 110/390, d1=0.562, d2=0.436 g=2.133
# >191, 111/390, d1=0.491, d2=0.634 g=2.223
# >191, 112/390, d1=0.447, d2=0.479 g=2.221
# >191, 113/390, d1=0.586, d2=0.423 g=2.107
# >191, 114/390, d1=0.503, d2=0.619 g=2.205
# >191, 115/390, d1=0.574, d2=0.522 g=2.111
# >191, 116/390, d1=0.503, d2=0.456 g=2.140
# >191, 117/390, d1=0.681, d2=0.398 g=2.123
# >191, 118/390, d1=0.477, d2=0.591 g=2.131
# >191, 119/390, d1=0.570, d2=0.485 g=2.132
# >191, 120/390, d1=0.495, d2=0.494 g=2.128
# >191, 121/390, d1=0.543, d2=0.479 g=2.070
# >191, 122/390, d1=0.540, d2=0.495 g=2.133
# >191, 123/390, d1=0.400, d2=0.448 g=2.237
# >191, 124/390, d1=0.523, d2=0.367 g=2.174
# >191, 125/390, d1=0.539, d2=0.453 g=2.090
# >191, 126/390, d1=0.514, d2=0.443 g=2.074
# >191, 127/390, d1=0.510, d2=0.508 g=2.173
# >191, 128/390, d1=0.488, d2=0.507 g=2.181
# >191, 129/390, d1=0.558, d2=0.435 g=2.160
# >191, 130/390, d1=0.486, d2=0.425 g=2.240
# >191, 131/390, d1=0.484, d2=0.412 g=2.088
# >191, 132/390, d1=0.536, d2=0.487 g=2.077
# >191, 133/390, d1=0.420, d2=0.477 g=2.163
# >191, 134/390, d1=0.491, d2=0.660 g=2.078
# >191, 135/390, d1=0.498, d2=0.454 g=2.226
# >191, 136/390, d1=0.538, d2=0.443 g=2.263
# >191, 137/390, d1=0.593, d2=0.542 g=2.289
# >191, 138/390, d1=0.569, d2=0.545 g=2.347
# >191, 139/390, d1=0.454, d2=0.366 g=2.167
# >191, 140/390, d1=0.634, d2=0.418 g=2.095
# >191, 141/390, d1=0.470, d2=0.598 g=2.038
# >191, 142/390, d1=0.544, d2=0.637 g=2.187
# >191, 143/390, d1=0.631, d2=0.484 g=2.135
# >191, 144/390, d1=0.629, d2=0.576 g=2.158
# >191, 145/390, d1=0.476, d2=0.476 g=2.178
# >191, 146/390, d1=0.560, d2=0.405 g=2.160
# >191, 147/390, d1=0.448, d2=0.401 g=2.224
# >191, 148/390, d1=0.476, d2=0.516 g=2.077
# >191, 149/390, d1=0.588, d2=0.625 g=2.179
# >191, 150/390, d1=0.553, d2=0.525 g=2.207
# >191, 151/390, d1=0.632, d2=0.541 g=2.097
# >191, 152/390, d1=0.415, d2=0.699 g=2.214
# >191, 153/390, d1=0.651, d2=0.716 g=2.330
# >191, 154/390, d1=0.588, d2=0.471 g=2.196
# >191, 155/390, d1=0.512, d2=0.550 g=2.197
# >191, 156/390, d1=0.555, d2=0.388 g=2.150
# >191, 157/390, d1=0.691, d2=0.437 g=2.103
# >191, 158/390, d1=0.420, d2=0.596 g=2.263
# >191, 159/390, d1=0.539, d2=0.493 g=2.179
# >191, 160/390, d1=0.569, d2=0.474 g=2.226
# >191, 161/390, d1=0.511, d2=0.580 g=2.206
# >191, 162/390, d1=0.510, d2=0.397 g=2.262
# >191, 163/390, d1=0.375, d2=0.525 g=2.285
# >191, 164/390, d1=0.654, d2=0.591 g=2.323
# >191, 165/390, d1=0.570, d2=0.444 g=2.148
# >191, 166/390, d1=0.575, d2=0.636 g=2.259
# >191, 167/390, d1=0.529, d2=0.501 g=2.295
# >191, 168/390, d1=0.516, d2=0.493 g=2.266
# >191, 169/390, d1=0.547, d2=0.335 g=2.304
# >191, 170/390, d1=0.408, d2=0.573 g=2.286
# >191, 171/390, d1=0.627, d2=0.456 g=2.077
# >191, 172/390, d1=0.528, d2=0.496 g=2.196
# >191, 173/390, d1=0.498, d2=0.446 g=2.232
# >191, 174/390, d1=0.574, d2=0.443 g=2.190
# >191, 175/390, d1=0.485, d2=0.446 g=1.997
# >191, 176/390, d1=0.592, d2=0.717 g=2.198
# >191, 177/390, d1=0.570, d2=0.429 g=2.198
# >191, 178/390, d1=0.550, d2=0.441 g=2.144
# >191, 179/390, d1=0.579, d2=0.495 g=2.104
# >191, 180/390, d1=0.467, d2=0.469 g=2.096
# >191, 181/390, d1=0.629, d2=0.454 g=2.153
# >191, 182/390, d1=0.488, d2=0.507 g=2.079
# >191, 183/390, d1=0.492, d2=0.498 g=2.003
# >191, 184/390, d1=0.451, d2=0.636 g=2.229
# >191, 185/390, d1=0.505, d2=0.429 g=2.252
# >191, 186/390, d1=0.548, d2=0.526 g=2.218
# >191, 187/390, d1=0.521, d2=0.489 g=2.245
# >191, 188/390, d1=0.559, d2=0.461 g=2.253
# >191, 189/390, d1=0.531, d2=0.483 g=2.251
# >191, 190/390, d1=0.579, d2=0.506 g=2.246
# >191, 191/390, d1=0.586, d2=0.518 g=2.177
# >191, 192/390, d1=0.505, d2=0.523 g=2.129
# >191, 193/390, d1=0.547, d2=0.452 g=2.196
# >191, 194/390, d1=0.469, d2=0.586 g=2.161
# >191, 195/390, d1=0.554, d2=0.440 g=2.305
# >191, 196/390, d1=0.529, d2=0.452 g=2.286
# >191, 197/390, d1=0.529, d2=0.496 g=2.291
# >191, 198/390, d1=0.630, d2=0.465 g=2.011
# >191, 199/390, d1=0.471, d2=0.495 g=2.151
# >191, 200/390, d1=0.532, d2=0.467 g=2.066
# >191, 201/390, d1=0.515, d2=0.591 g=2.196
# >191, 202/390, d1=0.524, d2=0.418 g=2.190
# >191, 203/390, d1=0.542, d2=0.478 g=2.107
# >191, 204/390, d1=0.620, d2=0.428 g=2.168
# >191, 205/390, d1=0.521, d2=0.542 g=2.025
# >191, 206/390, d1=0.350, d2=0.500 g=2.119
# >191, 207/390, d1=0.506, d2=0.429 g=2.108
# >191, 208/390, d1=0.616, d2=0.487 g=2.119
# >191, 209/390, d1=0.495, d2=0.516 g=2.120
# >191, 210/390, d1=0.470, d2=0.456 g=2.180
# >191, 211/390, d1=0.559, d2=0.535 g=2.202
# >191, 212/390, d1=0.627, d2=0.455 g=2.167
# >191, 213/390, d1=0.443, d2=0.534 g=2.190
# >191, 214/390, d1=0.631, d2=0.501 g=2.189
# >191, 215/390, d1=0.553, d2=0.568 g=2.215
# >191, 216/390, d1=0.504, d2=0.463 g=2.058
# >191, 217/390, d1=0.565, d2=0.543 g=2.085
# >191, 218/390, d1=0.576, d2=0.532 g=2.008
# >191, 219/390, d1=0.537, d2=0.505 g=2.142
# >191, 220/390, d1=0.551, d2=0.398 g=2.106
# >191, 221/390, d1=0.430, d2=0.541 g=2.268
# >191, 222/390, d1=0.602, d2=0.500 g=2.208
# >191, 223/390, d1=0.548, d2=0.512 g=2.194
# >191, 224/390, d1=0.600, d2=0.428 g=2.167
# >191, 225/390, d1=0.596, d2=0.514 g=2.026
# >191, 226/390, d1=0.475, d2=0.499 g=2.085
# >191, 227/390, d1=0.614, d2=0.473 g=2.091
# >191, 228/390, d1=0.282, d2=0.506 g=2.207
# >191, 229/390, d1=0.438, d2=0.538 g=2.109
# >191, 230/390, d1=0.461, d2=0.429 g=2.383
# >191, 231/390, d1=0.562, d2=0.466 g=2.265
# >191, 232/390, d1=0.588, d2=0.514 g=2.163
# >191, 233/390, d1=0.573, d2=0.480 g=2.283
# >191, 234/390, d1=0.603, d2=0.488 g=1.925
# >191, 235/390, d1=0.605, d2=0.495 g=2.113
# >191, 236/390, d1=0.528, d2=0.544 g=2.035
# >191, 237/390, d1=0.539, d2=0.537 g=2.042
# >191, 238/390, d1=0.525, d2=0.489 g=2.113
# >191, 239/390, d1=0.440, d2=0.472 g=2.180
# >191, 240/390, d1=0.584, d2=0.437 g=2.350
# >191, 241/390, d1=0.516, d2=0.507 g=2.081
# >191, 242/390, d1=0.502, d2=0.386 g=2.103
# >191, 243/390, d1=0.498, d2=0.472 g=2.120
# >191, 244/390, d1=0.504, d2=0.469 g=2.023
# >191, 245/390, d1=0.508, d2=0.520 g=2.146
# >191, 246/390, d1=0.527, d2=0.471 g=2.236
# >191, 247/390, d1=0.482, d2=0.546 g=2.016
# >191, 248/390, d1=0.528, d2=0.578 g=2.078
# >191, 249/390, d1=0.588, d2=0.561 g=2.228
# >191, 250/390, d1=0.628, d2=0.428 g=2.062
# >191, 251/390, d1=0.511, d2=0.489 g=2.179
# >191, 252/390, d1=0.635, d2=0.493 g=2.017
# >191, 253/390, d1=0.429, d2=0.527 g=2.144
# >191, 254/390, d1=0.528, d2=0.543 g=2.240
# >191, 255/390, d1=0.589, d2=0.469 g=2.154
# >191, 256/390, d1=0.603, d2=0.446 g=2.158
# >191, 257/390, d1=0.520, d2=0.368 g=2.202
# >191, 258/390, d1=0.493, d2=0.525 g=2.034
# >191, 259/390, d1=0.406, d2=0.511 g=2.275
# >191, 260/390, d1=0.417, d2=0.472 g=2.176
# >191, 261/390, d1=0.573, d2=0.505 g=2.091
# >191, 262/390, d1=0.633, d2=0.473 g=2.080
# >191, 263/390, d1=0.551, d2=0.499 g=2.049
# >191, 264/390, d1=0.497, d2=0.475 g=2.144
# >191, 265/390, d1=0.531, d2=0.618 g=2.153
# >191, 266/390, d1=0.576, d2=0.481 g=2.146
# >191, 267/390, d1=0.572, d2=0.521 g=2.051
# >191, 268/390, d1=0.496, d2=0.561 g=2.224
# >191, 269/390, d1=0.574, d2=0.440 g=2.217
# >191, 270/390, d1=0.515, d2=0.496 g=2.214
# >191, 271/390, d1=0.613, d2=0.486 g=2.185
# >191, 272/390, d1=0.493, d2=0.498 g=2.177
# >191, 273/390, d1=0.516, d2=0.449 g=2.180
# >191, 274/390, d1=0.657, d2=0.496 g=2.182
# >191, 275/390, d1=0.408, d2=0.386 g=2.112
# >191, 276/390, d1=0.472, d2=0.561 g=2.282
# >191, 277/390, d1=0.413, d2=0.511 g=2.300
# >191, 278/390, d1=0.583, d2=0.465 g=2.266
# >191, 279/390, d1=0.604, d2=0.542 g=2.253
# >191, 280/390, d1=0.604, d2=0.389 g=2.126
# >191, 281/390, d1=0.519, d2=0.675 g=2.055
# >191, 282/390, d1=0.512, d2=0.544 g=2.182
# >191, 283/390, d1=0.572, d2=0.447 g=2.109
# >191, 284/390, d1=0.618, d2=0.513 g=2.142
# >191, 285/390, d1=0.519, d2=0.499 g=2.287
# >191, 286/390, d1=0.522, d2=0.521 g=2.204
# >191, 287/390, d1=0.580, d2=0.455 g=2.066
# >191, 288/390, d1=0.518, d2=0.549 g=2.117
# >191, 289/390, d1=0.517, d2=0.493 g=2.073
# >191, 290/390, d1=0.441, d2=0.558 g=2.115
# >191, 291/390, d1=0.566, d2=0.564 g=2.138
# >191, 292/390, d1=0.560, d2=0.549 g=2.082
# >191, 293/390, d1=0.482, d2=0.434 g=2.261
# >191, 294/390, d1=0.426, d2=0.466 g=2.255
# >191, 295/390, d1=0.403, d2=0.445 g=2.088
# >191, 296/390, d1=0.572, d2=0.435 g=2.246
# >191, 297/390, d1=0.617, d2=0.478 g=2.133
# >191, 298/390, d1=0.526, d2=0.492 g=2.208
# >191, 299/390, d1=0.513, d2=0.481 g=2.093
# >191, 300/390, d1=0.392, d2=0.473 g=2.156
# >191, 301/390, d1=0.496, d2=0.446 g=2.230
# >191, 302/390, d1=0.508, d2=0.516 g=2.198
# >191, 303/390, d1=0.615, d2=0.427 g=2.106
# >191, 304/390, d1=0.572, d2=0.547 g=2.150
# >191, 305/390, d1=0.562, d2=0.364 g=2.144
# >191, 306/390, d1=0.525, d2=0.530 g=2.146
# >191, 307/390, d1=0.531, d2=0.514 g=2.079
# >191, 308/390, d1=0.475, d2=0.513 g=2.065
# >191, 309/390, d1=0.520, d2=0.728 g=2.265
# >191, 310/390, d1=0.551, d2=0.451 g=2.286
# >191, 311/390, d1=0.494, d2=0.510 g=2.245
# >191, 312/390, d1=0.576, d2=0.588 g=2.223
# >191, 313/390, d1=0.614, d2=0.549 g=2.136
# >191, 314/390, d1=0.578, d2=0.556 g=2.175
# >191, 315/390, d1=0.569, d2=0.598 g=2.019
# >191, 316/390, d1=0.573, d2=0.527 g=2.280
# >191, 317/390, d1=0.562, d2=0.471 g=2.193
# >191, 318/390, d1=0.471, d2=0.564 g=2.272
# >191, 319/390, d1=0.517, d2=0.469 g=2.175
# >191, 320/390, d1=0.490, d2=0.474 g=2.258
# >191, 321/390, d1=0.595, d2=0.491 g=2.186
# >191, 322/390, d1=0.554, d2=0.454 g=2.220
# >191, 323/390, d1=0.486, d2=0.581 g=2.225
# >191, 324/390, d1=0.585, d2=0.438 g=2.017
# >191, 325/390, d1=0.512, d2=0.479 g=2.068
# >191, 326/390, d1=0.465, d2=0.555 g=2.122
# >191, 327/390, d1=0.458, d2=0.466 g=2.375
# >191, 328/390, d1=0.533, d2=0.470 g=2.254
# >191, 329/390, d1=0.574, d2=0.448 g=2.298
# >191, 330/390, d1=0.437, d2=0.441 g=2.086
# >191, 331/390, d1=0.601, d2=0.529 g=2.221
# >191, 332/390, d1=0.473, d2=0.422 g=2.189
# >191, 333/390, d1=0.542, d2=0.485 g=2.179
# >191, 334/390, d1=0.539, d2=0.418 g=2.221
# >191, 335/390, d1=0.426, d2=0.442 g=2.315
# >191, 336/390, d1=0.471, d2=0.451 g=2.078
# >191, 337/390, d1=0.572, d2=0.524 g=2.228
# >191, 338/390, d1=0.519, d2=0.462 g=2.122
# >191, 339/390, d1=0.491, d2=0.522 g=2.093
# >191, 340/390, d1=0.509, d2=0.477 g=2.176
# >191, 341/390, d1=0.536, d2=0.445 g=2.240
# >191, 342/390, d1=0.584, d2=0.501 g=2.111
# >191, 343/390, d1=0.524, d2=0.618 g=2.152
# >191, 344/390, d1=0.476, d2=0.523 g=2.272
# >191, 345/390, d1=0.592, d2=0.516 g=2.308
# >191, 346/390, d1=0.530, d2=0.507 g=2.156
# >191, 347/390, d1=0.567, d2=0.553 g=2.387
# >191, 348/390, d1=0.638, d2=0.389 g=2.283
# >191, 349/390, d1=0.647, d2=0.460 g=2.155
# >191, 350/390, d1=0.569, d2=0.481 g=2.185
# >191, 351/390, d1=0.606, d2=0.585 g=2.030
# >191, 352/390, d1=0.563, d2=0.565 g=2.163
# >191, 353/390, d1=0.535, d2=0.512 g=2.089
# >191, 354/390, d1=0.539, d2=0.567 g=2.073
# >191, 355/390, d1=0.505, d2=0.542 g=2.136
# >191, 356/390, d1=0.471, d2=0.428 g=2.172
# >191, 357/390, d1=0.639, d2=0.521 g=2.086
# >191, 358/390, d1=0.465, d2=0.750 g=2.115
# >191, 359/390, d1=0.467, d2=0.513 g=2.339
# >191, 360/390, d1=0.638, d2=0.432 g=2.208
# >191, 361/390, d1=0.588, d2=0.606 g=2.083
# >191, 362/390, d1=0.474, d2=0.502 g=2.106
# >191, 363/390, d1=0.542, d2=0.473 g=2.299
# >191, 364/390, d1=0.620, d2=0.471 g=2.142
# >191, 365/390, d1=0.600, d2=0.549 g=2.136
# >191, 366/390, d1=0.422, d2=0.532 g=2.242
# >191, 367/390, d1=0.521, d2=0.499 g=2.165
# >191, 368/390, d1=0.531, d2=0.467 g=2.181
# >191, 369/390, d1=0.447, d2=0.366 g=2.129
# >191, 370/390, d1=0.457, d2=0.672 g=2.248
# >191, 371/390, d1=0.552, d2=0.587 g=2.229
# >191, 372/390, d1=0.656, d2=0.531 g=2.278
# >191, 373/390, d1=0.560, d2=0.398 g=2.147
# >191, 374/390, d1=0.549, d2=0.532 g=2.182
# >191, 375/390, d1=0.594, d2=0.504 g=2.216
# >191, 376/390, d1=0.559, d2=0.459 g=2.093
# >191, 377/390, d1=0.536, d2=0.547 g=2.240
# >191, 378/390, d1=0.556, d2=0.485 g=2.254
# >191, 379/390, d1=0.608, d2=0.499 g=2.171
# >191, 380/390, d1=0.561, d2=0.540 g=2.132
# >191, 381/390, d1=0.510, d2=0.517 g=2.257
# >191, 382/390, d1=0.477, d2=0.395 g=2.116
# >191, 383/390, d1=0.466, d2=0.519 g=2.136
# >191, 384/390, d1=0.345, d2=0.486 g=2.157
# >191, 385/390, d1=0.586, d2=0.382 g=2.183
# >191, 386/390, d1=0.625, d2=0.678 g=2.140
# >191, 387/390, d1=0.431, d2=0.576 g=2.268
# >191, 388/390, d1=0.585, d2=0.348 g=2.227
# >191, 389/390, d1=0.663, d2=0.428 g=2.145
# >191, 390/390, d1=0.527, d2=0.525 g=1.978
# >192, 1/390, d1=0.450, d2=0.548 g=2.120
# >192, 2/390, d1=0.521, d2=0.625 g=2.302
# >192, 3/390, d1=0.423, d2=0.496 g=2.246
# >192, 4/390, d1=0.693, d2=0.436 g=2.156
# >192, 5/390, d1=0.426, d2=0.430 g=2.278
# >192, 6/390, d1=0.415, d2=0.540 g=2.144
# >192, 7/390, d1=0.623, d2=0.456 g=2.184
# >192, 8/390, d1=0.630, d2=0.496 g=2.171
# >192, 9/390, d1=0.497, d2=0.608 g=2.117
# >192, 10/390, d1=0.567, d2=0.466 g=2.204
# >192, 11/390, d1=0.671, d2=0.550 g=2.094
# >192, 12/390, d1=0.467, d2=0.511 g=2.179
# >192, 13/390, d1=0.558, d2=0.379 g=2.129
# >192, 14/390, d1=0.607, d2=0.525 g=2.093
# >192, 15/390, d1=0.562, d2=0.553 g=2.050
# >192, 16/390, d1=0.403, d2=0.504 g=2.032
# >192, 17/390, d1=0.495, d2=0.510 g=2.100
# >192, 18/390, d1=0.515, d2=0.393 g=2.191
# >192, 19/390, d1=0.546, d2=0.504 g=1.981
# >192, 20/390, d1=0.482, d2=0.555 g=2.053
# >192, 21/390, d1=0.487, d2=0.481 g=2.253
# >192, 22/390, d1=0.454, d2=0.715 g=2.259
# >192, 23/390, d1=0.470, d2=0.505 g=2.262
# >192, 24/390, d1=0.692, d2=0.398 g=2.220
# >192, 25/390, d1=0.625, d2=0.493 g=2.132
# >192, 26/390, d1=0.556, d2=0.462 g=2.010
# >192, 27/390, d1=0.540, d2=0.597 g=2.022
# >192, 28/390, d1=0.579, d2=0.452 g=2.120
# >192, 29/390, d1=0.549, d2=0.494 g=2.084
# >192, 30/390, d1=0.457, d2=0.505 g=2.164
# >192, 31/390, d1=0.494, d2=0.535 g=2.091
# >192, 32/390, d1=0.482, d2=0.431 g=2.233
# >192, 33/390, d1=0.659, d2=0.578 g=2.268
# >192, 34/390, d1=0.492, d2=0.505 g=2.106
# >192, 35/390, d1=0.642, d2=0.495 g=2.072
# >192, 36/390, d1=0.525, d2=0.460 g=2.122
# >192, 37/390, d1=0.500, d2=0.583 g=2.103
# >192, 38/390, d1=0.542, d2=0.524 g=2.066
# >192, 39/390, d1=0.613, d2=0.503 g=2.155
# >192, 40/390, d1=0.507, d2=0.614 g=2.171
# >192, 41/390, d1=0.528, d2=0.411 g=2.264
# >192, 42/390, d1=0.625, d2=0.525 g=2.210
# >192, 43/390, d1=0.510, d2=0.478 g=2.161
# >192, 44/390, d1=0.623, d2=0.496 g=2.028
# >192, 45/390, d1=0.511, d2=0.500 g=2.083
# ...
# >200, 334/390, d1=0.407, d2=0.427 g=2.191
# >Accuracy real: 78%, fake: 92% 	 >D2 Accuracy real: 43%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 335/390, d1=0.416, d2=0.478 g=2.175
# >Accuracy real: 69%, fake: 92% 	 >D2 Accuracy real: 52%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 336/390, d1=0.436, d2=0.555 g=2.239
# >Accuracy real: 74%, fake: 93% 	 >D2 Accuracy real: 51%, fake: 57%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 337/390, d1=0.416, d2=0.520 g=2.237
# >Accuracy real: 73%, fake: 93% 	 >D2 Accuracy real: 55%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 338/390, d1=0.383, d2=0.486 g=2.232
# >Accuracy real: 66%, fake: 95% 	 >D2 Accuracy real: 40%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 339/390, d1=0.369, d2=0.443 g=2.204
# >Accuracy real: 70%, fake: 94% 	 >D2 Accuracy real: 43%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 340/390, d1=0.427, d2=0.447 g=2.106
# >Accuracy real: 79%, fake: 87% 	 >D2 Accuracy real: 57%, fake: 61%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 341/390, d1=0.452, d2=0.588 g=2.187
# >Accuracy real: 77%, fake: 91% 	 >D2 Accuracy real: 47%, fake: 61%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 342/390, d1=0.433, d2=0.477 g=2.364
# >Accuracy real: 80%, fake: 93% 	 >D2 Accuracy real: 45%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 343/390, d1=0.397, d2=0.524 g=2.339
# >Accuracy real: 71%, fake: 94% 	 >D2 Accuracy real: 48%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 344/390, d1=0.395, d2=0.359 g=2.326
# >Accuracy real: 73%, fake: 90% 	 >D2 Accuracy real: 48%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 345/390, d1=0.419, d2=0.493 g=2.206
# >Accuracy real: 77%, fake: 93% 	 >D2 Accuracy real: 49%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 346/390, d1=0.439, d2=0.544 g=2.233
# >Accuracy real: 71%, fake: 91% 	 >D2 Accuracy real: 59%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 347/390, d1=0.428, d2=0.451 g=2.206
# >Accuracy real: 70%, fake: 93% 	 >D2 Accuracy real: 48%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 348/390, d1=0.401, d2=0.504 g=2.326
# >Accuracy real: 69%, fake: 91% 	 >D2 Accuracy real: 49%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 349/390, d1=0.415, d2=0.486 g=2.308
# >Accuracy real: 70%, fake: 98% 	 >D2 Accuracy real: 43%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 350/390, d1=0.402, d2=0.508 g=2.225
# >Accuracy real: 73%, fake: 91% 	 >D2 Accuracy real: 64%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 351/390, d1=0.389, d2=0.411 g=2.207
# >Accuracy real: 65%, fake: 95% 	 >D2 Accuracy real: 48%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 352/390, d1=0.362, d2=0.504 g=2.227
# >Accuracy real: 73%, fake: 95% 	 >D2 Accuracy real: 48%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 353/390, d1=0.409, d2=0.435 g=2.240
# >Accuracy real: 73%, fake: 95% 	 >D2 Accuracy real: 48%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 354/390, d1=0.385, d2=0.428 g=2.232
# >Accuracy real: 71%, fake: 90% 	 >D2 Accuracy real: 48%, fake: 63%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 355/390, d1=0.416, d2=0.533 g=2.175
# >Accuracy real: 72%, fake: 96% 	 >D2 Accuracy real: 49%, fake: 80%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 356/390, d1=0.375, d2=0.443 g=2.093
# >Accuracy real: 76%, fake: 92% 	 >D2 Accuracy real: 53%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 357/390, d1=0.425, d2=0.540 g=2.250
# >Accuracy real: 71%, fake: 88% 	 >D2 Accuracy real: 55%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 358/390, d1=0.412, d2=0.443 g=2.057
# >Accuracy real: 68%, fake: 89% 	 >D2 Accuracy real: 43%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 359/390, d1=0.411, d2=0.557 g=2.278
# >Accuracy real: 71%, fake: 97% 	 >D2 Accuracy real: 52%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 360/390, d1=0.400, d2=0.513 g=2.150
# >Accuracy real: 73%, fake: 92% 	 >D2 Accuracy real: 56%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 361/390, d1=0.405, d2=0.497 g=2.163
# >Accuracy real: 76%, fake: 83% 	 >D2 Accuracy real: 55%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 362/390, d1=0.485, d2=0.529 g=2.214
# >Accuracy real: 72%, fake: 87% 	 >D2 Accuracy real: 45%, fake: 67%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 363/390, d1=0.427, d2=0.388 g=2.259
# >Accuracy real: 76%, fake: 92% 	 >D2 Accuracy real: 47%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 364/390, d1=0.418, d2=0.580 g=2.227
# >Accuracy real: 72%, fake: 87% 	 >D2 Accuracy real: 48%, fake: 64%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 365/390, d1=0.450, d2=0.465 g=2.323
# >Accuracy real: 73%, fake: 85% 	 >D2 Accuracy real: 48%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 366/390, d1=0.444, d2=0.637 g=2.263
# >Accuracy real: 70%, fake: 94% 	 >D2 Accuracy real: 57%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 367/390, d1=0.433, d2=0.610 g=2.289
# >Accuracy real: 74%, fake: 96% 	 >D2 Accuracy real: 39%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 368/390, d1=0.366, d2=0.454 g=2.233
# >Accuracy real: 55%, fake: 91% 	 >D2 Accuracy real: 43%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 369/390, d1=0.453, d2=0.395 g=2.262
# >Accuracy real: 70%, fake: 86% 	 >D2 Accuracy real: 45%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 370/390, d1=0.473, d2=0.592 g=2.023
# >Accuracy real: 70%, fake: 89% 	 >D2 Accuracy real: 51%, fake: 75%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 371/390, d1=0.407, d2=0.499 g=2.224
# >Accuracy real: 73%, fake: 87% 	 >D2 Accuracy real: 52%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 372/390, d1=0.435, d2=0.559 g=2.199
# >Accuracy real: 72%, fake: 89% 	 >D2 Accuracy real: 40%, fake: 65%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 373/390, d1=0.444, d2=0.523 g=2.256
# >Accuracy real: 62%, fake: 93% 	 >D2 Accuracy real: 43%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 374/390, d1=0.394, d2=0.495 g=2.292
# >Accuracy real: 67%, fake: 93% 	 >D2 Accuracy real: 44%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 375/390, d1=0.440, d2=0.471 g=2.154
# >Accuracy real: 69%, fake: 91% 	 >D2 Accuracy real: 39%, fake: 76%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 376/390, d1=0.436, d2=0.438 g=2.183
# >Accuracy real: 79%, fake: 86% 	 >D2 Accuracy real: 57%, fake: 68%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 377/390, d1=0.438, d2=0.478 g=2.128
# >Accuracy real: 76%, fake: 89% 	 >D2 Accuracy real: 47%, fake: 69%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 378/390, d1=0.482, d2=0.531 g=2.088
# >Accuracy real: 75%, fake: 85% 	 >D2 Accuracy real: 44%, fake: 60%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 379/390, d1=0.422, d2=0.524 g=2.257
# >Accuracy real: 75%, fake: 87% 	 >D2 Accuracy real: 57%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 380/390, d1=0.443, d2=0.544 g=2.241
# >Accuracy real: 76%, fake: 91% 	 >D2 Accuracy real: 39%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 381/390, d1=0.383, d2=0.503 g=2.281
# >Accuracy real: 73%, fake: 94% 	 >D2 Accuracy real: 47%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 382/390, d1=0.387, d2=0.403 g=2.140
# >Accuracy real: 61%, fake: 98% 	 >D2 Accuracy real: 48%, fake: 79%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 383/390, d1=0.403, d2=0.410 g=2.127
# >Accuracy real: 71%, fake: 93% 	 >D2 Accuracy real: 51%, fake: 77%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 384/390, d1=0.429, d2=0.526 g=2.122
# >Accuracy real: 77%, fake: 89% 	 >D2 Accuracy real: 52%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 385/390, d1=0.411, d2=0.455 g=2.207
# >Accuracy real: 77%, fake: 92% 	 >D2 Accuracy real: 47%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 386/390, d1=0.428, d2=0.487 g=2.033
# >Accuracy real: 73%, fake: 93% 	 >D2 Accuracy real: 45%, fake: 71%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 387/390, d1=0.423, d2=0.538 g=2.055
# >Accuracy real: 68%, fake: 93% 	 >D2 Accuracy real: 51%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 388/390, d1=0.430, d2=0.433 g=2.248
# >Accuracy real: 76%, fake: 93% 	 >D2 Accuracy real: 48%, fake: 72%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 389/390, d1=0.424, d2=0.504 g=2.181
# >Accuracy real: 78%, fake: 93% 	 >D2 Accuracy real: 48%, fake: 81%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# >200, 390/390, d1=0.400, d2=0.519 g=2.105
# >Accuracy real: 78%, fake: 85% 	 >D2 Accuracy real: 36%, fake: 73%
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
generator = g_model
generator.load_weights("/content/generator_model_190.h5")
print("Loaded model from disk")
# Out:
# Loaded model from disk

# %%
import math
import tensorflow as tf
import time
from numpy import cov
from numpy import trace
from numpy import iscomplexobj
from numpy.random import random
from scipy.linalg import sqrtm
from numpy import expand_dims
from keras.models import load_model
from numpy.random import randn
from keras.models import model_from_json
from keras.datasets import mnist
import numpy as np
import random
from keras.applications.inception_v3 import preprocess_input
from skimage.transform import resize
from keras.applications.inception_v3 import InceptionV3

# (x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
# x_train = x_train / 127.5 - 1.
# x_test = x_test / 127.5 - 1.
# print(x_train.shape)

# json_file = open('/content/output/generator.json', 'r')
# loaded_model_json = json_file.read()
# json_file.close()
# generator = model_from_json(loaded_model_json)
# generator.load_weights("/content/output/generator.h5")
# print("Loaded model from disk")

def scale_images(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return np.asarray(images_list)
 
 # calculate frechet inception distance
def calculate_fid(model, images1, images2):
	# calculate activations
	act1 = model.predict(images1)
	act2 = model.predict(images2)
	# calculate mean and covariance statistics
	mu1, sigma1 = act1.mean(axis=0), cov(act1, rowvar=False)
	mu2, sigma2 = act2.mean(axis=0), cov(act2, rowvar=False)
	# calculate sum squared difference between means
	ssdiff = np.sum((mu1 - mu2)**2.0)
	# calculate sqrt of product between cov
	covmean = sqrtm(sigma1.dot(sigma2))
	# check and correct imaginary numbers from sqrt
	if iscomplexobj(covmean):
		covmean = covmean.real
	# calculate score
	fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
	return fid

model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))

# %%
for i in range(12):
    imgs_num = 500
    idx = np.random.randint(0, dataset.shape[0], imgs_num)
    # define two collections of 500 images
    reals = dataset[idx]
    # reals = reals.reshape((imgs_num,32,32,3))
    noise = np.random.normal(0, 1, (imgs_num, 100))
    # Generate a batch of new images
    fakes = g_model.predict(noise)
    gen_imgs = fakes
    fakes = fakes.reshape((imgs_num,32,32,3))
    # resize images
    reals = scale_images(reals, (299,299,3))
    fakes = scale_images(fakes, (299,299,3))
    reals = preprocess_input(reals)
    fakes = preprocess_input(fakes)
    # fid between images1 and images2
    fid = calculate_fid(model, reals, fakes)
    print('FID: %.3f' % fid)
# Out:
# FID: 1.272
# FID: 1.426
# FID: 0.880
# FID: 1.113
# FID: 0.951
# FID: 1.487
# FID: 0.815
# FID: 0.889
# FID: 1.084
# FID: 0.956
# FID: 0.771
# FID: 1.192

# %% [markdown]
# FID:
#
#
# 1.   0.895
#
# 2.   0.915
# 3.0.804
# 4.0.803
# 5.0.740

# %%
# calculate inception score for cifar-10 in Keras
from math import floor
from numpy import ones
from numpy import expand_dims
from numpy import log
from numpy import mean
from numpy import std
from numpy import exp
from numpy.random import shuffle
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.datasets import mnist
from skimage.transform import resize
from numpy import asarray

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
x_train = x_train / 127.5 - 1.
x_test = x_test / 127.5 - 1.
print(x_train.shape)


# scale an array of images to a new size
def scale_images(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return asarray(images_list)

# assumes images have any shape and pixels in [0,255]
def calculate_inception_score(images, n_split=10, eps=1E-16):
	# load inception v3 model
	model = InceptionV3()
	# enumerate splits of images/predictions
	scores = list()
	n_part = floor(images.shape[0] / n_split)
	for i in range(n_split):
		# retrieve images
		ix_start, ix_end = i * n_part, (i+1) * n_part
		subset = images[ix_start:ix_end]
		# convert from uint8 to float32
		subset = subset.astype('float32')
		# scale images to the required size
		subset = scale_images(subset, (299,299,3))
		# pre-process images, scale to [-1,1]
		# subset = preprocess_input(subset)
		# predict p(y|x)
		p_yx = model.predict(subset)
		# calculate p(y)
		p_y = expand_dims(p_yx.mean(axis=0), 0)
		# calculate KL divergence using log probabilities
		kl_d = p_yx * (log(p_yx + eps) - log(p_y + eps))
		# sum over classes
		sum_kl_d = kl_d.sum(axis=1)
		# average over images
		avg_kl_d = mean(sum_kl_d)
		# undo the log
		is_score = exp(avg_kl_d)
		# store
		scores.append(is_score)
	# average across images
	is_avg, is_std = mean(scores), std(scores)
	return is_avg, is_std

# load cifar10 images
# (images, _), (_, _) = mnist.load_data()
# shuffle images
images_reals = dataset[:1000]
shuffle(images_reals)
print('loaded', images_reals.shape)
# calculate inception score
is_avg, is_std = calculate_inception_score(images_reals)
print('score', is_avg, is_std)
# Out:
# (50000, 32, 32, 3)
# loaded (1000, 32, 32, 3)
# score 9.242806 0.8963166

# %%
# load cifar10 images
noise = np.random.normal(0, 1, (1000, 100))
# Generate a batch of new images
images = generator.predict(noise)
shuffle(images)
print('loaded', images.shape)
# calculate inception score
is_avg, is_std = calculate_inception_score(images)
print('score', is_avg, is_std)
# Out:
# loaded (1000, 32, 32, 3)
# score 5.976144 0.38315547

# %% [markdown]
# 1-5.9019713
#
# 2- 6.1320715
#
# 3- 6.6.052945
#
# 4- 6.458251
#
# 5-6.231183
